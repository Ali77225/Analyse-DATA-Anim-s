# %% [markdown]
# 1- Import du fichiers csv

# %%
import pandas as pd
import sns

# Chargement du fichier dans une variable appelée 'df' (pour DataFrame)
df = pd.read_csv('animes.csv')
# Attention : cela peut ralentir ton PC si le fichier est énorme
pd.set_option('display.max_rows', None)
df
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %% [markdown]
# 2- Mini audit

# %%
print("Valeurs manquantes par colonne :")
display(df.isna().sum())

print("\nNombre de doublons :", df.duplicated().sum())

print("\nTypes de colonnes :")
display(df.dtypes)
# Out:
# Valeurs manquantes par colonne :
# Anime                 0
# Genre_Tags            0
# Source                0
# Nb_Episodes           0
# Status                0
# Studio                0
# Date_Pub              0
# Note_Globale          0
# Note_Meilleur_Ep      0
# Meilleur_Ep_Titre     0
# Comm_Meilleur_Ep      0
# Note_Pire_Ep          0
# Pire_Ep_Titre         0
# Comm_Pire_Ep          0
# Comm_Saison_1         0
# Comm_Saison_2         0
# Comm_Saison_3        10
# dtype: int64
# Nombre de doublons : 2
#
# Types de colonnes :
# Anime                 object
# Genre_Tags            object
# Source                object
# Nb_Episodes            int64
# Status                object
# Studio                object
# Date_Pub              object
# Note_Globale         float64
# Note_Meilleur_Ep     float64
# Meilleur_Ep_Titre     object
# Comm_Meilleur_Ep      object
# Note_Pire_Ep         float64
# Pire_Ep_Titre         object
# Comm_Pire_Ep          object
# ...

# %% [markdown]
# Afficher les valeurs manquantes

# %%
print("--- Valeurs manquantes ---")
print(df.isna().sum())
# Out:
# --- Valeurs manquantes ---
# Anime                 0
# Genre_Tags            0
# Source                0
# Nb_Episodes           0
# Status                0
# Studio                0
# Date_Pub              0
# Note_Globale          0
# Note_Meilleur_Ep      0
# Meilleur_Ep_Titre     0
# Comm_Meilleur_Ep      0
# Note_Pire_Ep          0
# Pire_Ep_Titre         0
# Comm_Pire_Ep          0
# Comm_Saison_1         0
# Comm_Saison_2         0
# Comm_Saison_3        10
# dtype: int64

# %% [markdown]
# Affiher les types de colones

# %%
# 3. Afficher les types de colonnes
print("\n--- Types de colonnes ---")
print(df.dtypes)
# Out:
# --- Types de colonnes ---
# Anime                 object
# Genre_Tags            object
# Source                object
# Nb_Episodes            int64
# Status                object
# Studio                object
# Date_Pub              object
# Note_Globale         float64
# Note_Meilleur_Ep     float64
# Meilleur_Ep_Titre     object
# Comm_Meilleur_Ep      object
# Note_Pire_Ep         float64
# Pire_Ep_Titre         object
# Comm_Pire_Ep          object
# Comm_Saison_1         object
# Comm_Saison_2         object
# Comm_Saison_3         object
# dtype: object

# %% [markdown]
# Vérification mini audit

# %%
print("Valeurs manquantes par colonne :")
print(df.isna().sum())

print("\nNombre de doublons :", df.duplicated().sum())

print("\nTypes de colonnes :")
print(df.dtypes)
# Out:
# Valeurs manquantes par colonne :
# Anime                 0
# Genre_Tags            0
# Source                0
# Nb_Episodes           0
# Status                0
# Studio                0
# Date_Pub              0
# Note_Globale          0
# Note_Meilleur_Ep      0
# Meilleur_Ep_Titre     0
# Comm_Meilleur_Ep      0
# Note_Pire_Ep          0
# Pire_Ep_Titre         0
# Comm_Pire_Ep          0
# Comm_Saison_1         0
# Comm_Saison_2         0
# Comm_Saison_3        10
# dtype: int64
#
# Nombre de doublons : 2
#
# Types de colonnes :
# Anime                 object
# Genre_Tags            object
# Source                object
# Nb_Episodes            int64
# Status                object
# Studio                object
# Date_Pub              object
# Note_Globale         float64
# Note_Meilleur_Ep     float64
# Meilleur_Ep_Titre     object
# Comm_Meilleur_Ep      object
# Note_Pire_Ep         float64
# Pire_Ep_Titre         object
# Comm_Pire_Ep          object
# ...

# %% [markdown]
# 3- Nettoyage des données

# %%
# Copie pour éviter les warnings et garder un original
df_clean = df.copy()

# 0. Convertir Date en datetime (meilleure pratique)
df_clean['Date_Pub'] = pd.to_datetime(df_clean['Date_Pub'])

# 1. Supprimer les lignes avec valeurs manquantes (ici Produit)
df_clean = df_clean.dropna()

# 2. Supprimer les doublons
df_clean = df_clean.drop_duplicates()

# 3. Supprimer la colonne 'Studio' (non utilisée pour l'analyse ventes)
df_clean = df_clean.drop(columns=['Studio'])

print("Données nettoyées ! ✅")
display(df_clean)
# Out:
# Données nettoyées ! ✅
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %% [markdown]
# 4- Enrichissement des données

# %%
df_clean['Ecart'] = df_clean['Note_Meilleur_Ep'] - df_clean['Note_Pire_Ep']
df_clean['Regularite'] = 10 - df_clean['Ecart']
df_clean['Score_Qualite'] = (df_clean['Note_Globale'] * 0.6) + (df_clean   ['Regularite'] * 0.4)
display(df_clean)
# Out:
#                                Anime                    Genre_Tags  \
# 0                             Naruto               Action / Shonen
# 1                             Trigun               Sci-Fi / Action
# 2                      Dragon Ball Z               Action / Shonen
# 3   Fullmetal Alchemist: Brotherhood           Aventure / Military
# 4                       Cowboy Bebop                 Sci-Fi / Noir
# 5                   Sword Art Online              Isekai / Romance
# 6                            Re:Zero        Isekai / Psychologique
# 7                          Dr. Stone            Sci-Fi / Adventure
# 8                          One Piece            Adventure / Shonen
# 9                          Blue Lock              Sport / Thriller
# 10                         Haikyuu!!                Sport / Volley
# 11                     One Punch Man               Action / Comedy
# 12                     Solo Leveling              Action / Fantasy
# ...

# %% [markdown]
# 5- ANALYSE STATISTIQUE

# %%
ca_min = df_clean['Score_Qualite'].min()
ca_max = df_clean['Score_Qualite'].max()
ca_moyenne = df_clean['Score_Qualite'].mean()
ca_mediane = df_clean['Score_Qualite'].median()

print(f"le score_qualite minimal est: {ca_min:.2f}  | le score_qualite maximal est: {ca_max:.2f} ")
print(f"le score_qualite moyen est: {ca_moyenne:.2f}  | le mediane des score-qualite est: {ca_mediane:.2f} ")
# Out:
# le score_qualite minimal est: 5.36  | le score_qualite maximal est: 8.74
# le score_qualite moyen est: 7.89  | le mediane des score-qualite est: 8.06

# %% [markdown]
# Correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns


correlation = df_clean[['Score_Qualite', 'Note_Globale', 'Regularite', 'Nb_Episodes']].corr()
display(correlation)
plt.figure(figsize=(6,4))
sns.heatmap(correlation, annot=True, cmap='Blues', vmin=-1, vmax=1)
plt.title("Heatmap de corrélation")
plt.show()
# Out:
#                Score_Qualite  Note_Globale  Regularite  Nb_Episodes
# Score_Qualite       1.000000      0.657239    0.912425    -0.342469
# Note_Globale        0.657239      1.000000    0.291243    -0.036222
# Regularite          0.912425      0.291243    1.000000    -0.415028
# Nb_Episodes        -0.342469     -0.036222   -0.415028     1.000000

# %% [markdown]
# 6- Analyse par produit

# %%
resume_produits = df_clean.groupby('Anime').agg(
    SQ_Total=('Score_Qualite', 'sum'),
    Nb_Ep_Total=('Nb_Episodes', 'sum'),
    NG_moyenne=('Note_Globale', 'mean'),
    R_moyenne=('Regularite', 'mean')
).sort_values(by='SQ_Total', ascending=False)

resume_produits['Part_CA'] = (resume_produits['SQ_Total'] / resume_produits['SQ_Total'].sum()) * 100

display(resume_produits.style.format({
    'CA_Total': '{:.1f} €',
    'Prix_Moyen': '{:.2f} €',
    'CA_Moyen': '{:.2f} €',
    'Part_CA': '{:.1f} %'
}))
